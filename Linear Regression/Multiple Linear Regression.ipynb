# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("cars.csv")
df.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
from sklearn import linear_model 
reg = linear_model.LinearRegression()
reg.fit(df[['peakrpm','horsepower','enginesize']],df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([  0.87606091,  48.74328646, 132.67177482])

# %%
# Prediction of 1st row
reg.predict([[5000,111,130]])
# Out:
# array([13912.90432724])

# %%
reg.intercept_
# Out:
# -13125.235746663926

# %%
# Above the values is true
0.87606091 * 5000 + 48.74328646 * 111 + 132.67177482 * 130  + -13125.235746663926
# Out:
# 13912.904326996075
